# %%
from pdf2image import convert_from_path
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
pages = convert_from_path('1.pdf', 500)

# %%
pages = convert_from_path('trial.pdf')

# %%
pages

# %%
# import tempfile

with tempfile.TemporaryDirectory() as path:
#     images_from_path = convert_from_path('trial.pdf', 500, output_folder='D:\ECG Project')

# %%
nemo = cv2.imread('trial.ppm')
plt.imshow(nemo)
plt.show()

# %%
nemo = cv2.cvtColor(nemo, cv2.COLOR_BGR2RGB)
plt.imshow(nemo)
plt.show()

# %%
hsv_nemo = cv2.cvtColor(nemo, cv2.COLOR_RGB2HSV)
plt.imshow(hsv_nemo)
plt.show()

# %%
light_orange = (0, 0, 0)
dark_orange = (160, 255, 255)

# %%
mask = cv2.inRange(nemo, light_orange, dark_orange)

# %%
result = cv2.bitwise_and(nemo, nemo, mask=mask)

# %%
plt.subplot(1, 2, 1)
plt.imshow(mask, cmap="gray")
plt.subplot(1, 2, 2)
plt.imshow(result)
plt.show()
cv2.imwrite('masking.png', mask, [cv2.IMWRITE_PNG_COMPRESSION, 0])
cv2.imwrite('redmasking.png', mask, [cv2.IMWRITE_PNG_COMPRESSION, 0])
# Out:
# True

# %%
nemo = cv2.imread('gimpcropped.png')
plt.imshow(nemo)
plt.show()
nemo = cv2.cvtColor(nemo, cv2.COLOR_BGR2RGB)
plt.imshow(nemo)
plt.show()
hsv_nemo = cv2.cvtColor(nemo, cv2.COLOR_RGB2HSV)
plt.imshow(hsv_nemo)
plt.show()
light_orange = (0, 0, 0)
dark_orange = (165, 255, 255)
mask = cv2.inRange(nemo, light_orange, dark_orange)
result = cv2.bitwise_and(nemo, nemo, mask=mask)
# plt.subplot(1, 2, 1)
plt.imshow(mask, cmap="gray")
# plt.subplot(1, 2, 2)
# plt.imshow(result)
plt.show()
cv2.imwrite('maskingcropped.png', mask,[cv2.IMWRITE_PNG_COMPRESSION, 0])
# Out:
# True

# %%
im = cv2.imread('trial.ppm')
im_gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
th, im_gray_th_otsu = cv2.threshold(im_gray, 100, 250, cv2.THRESH_BINARY)
print(th)
# 117.0
plt.imshow(im_gray)
plt.imshow(im_gray_th_otsu, cmap='gray')
plt.show()

# cv2.imwrite('trialgrayscale.png', im_gray_th_otsu)

# %%
im = cv2.imread('textremovedtrial.png')
im_gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
th, im_gray_th_otsu = cv2.threshold(im_gray, 165, 255, cv2.THRESH_BINARY)
print(th)
# 117.0

plt.imshow(im_gray_th_otsu, cmap='gray')
plt.show()
cv2.imwrite('btextremovedwhite.png', im_gray_th_otsu)

# %%
im = cv2.imread('textremovedtrial.png')
im_gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
th, im_gray_th_otsu = cv2.threshold(im_gray, 150, 255, cv2.THRESH_BINARY_INV)
print(th)
# 117.0

plt.imshow(im_gray_th_otsu, cmap='gray')
plt.show()
cv2.imwrite('btextremoved1.png', im_gray_th_otsu)
# Out:
# 150.0
# True

# %%
im = cv2.imread('textremovedtrial.png')
im_gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
th, im_gray_th_otsu = cv2.threshold(im_gray, 170, 255, cv2.THRESH_BINARY_INV)
print(th)
# 117.0

plt.imshow(im_gray_th_otsu, cmap='gray')
plt.show()
cv2.imwrite('btextremoved3.png', im_gray_th_otsu)
# Out:
# 170.0
# True

# %%
import cv2, numpy as np

kernel = np.ones((1,20), np.uint8)  # note this is a horizontal kernel
d_im = cv2.dilate(bw, kernel, iterations=1)
e_im = cv2.erode(d_im, kernel, iterations=1)

# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt  
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (25,15)
# Reading the input image 
img = cv2.imread('masking.png', 0) 
  
# Taking a matrix of size 5 as the kernel 
kernel = np.ones((5,5), np.uint8) 
  
# The first parameter is the original image, 
# kernel is the matrix with which image is  
# convolved and third parameter is the number  
# of iterations, which will determine how much  
# you want to erode/dilate a given image.  
img_erosion = cv2.erode(img, kernel, iterations=1) 
img_dilation = cv2.dilate(img, kernel, iterations=1) 
  
plt.imshow(img, cmap='gray')
plt.show()
plt.imshow(img_erosion,cmap='gray')
plt.show()
plt.imshow(img_dilation,cmap='gray')
plt.show()
cv2.imwrite('maskeddilated.png', img_dilation)
# cv2.imshow('Erosion', img_erosion) 
# cv2.imshow('Dilation', img_dilation) 
  
# cv2.waitKey(0)
# Out:
# True

# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt  
# Reading the input image
plt.rcParams["figure.figsize"] = (25,15)
img = cv2.imread('maskingcropped.png', 0) 
  
# Taking a matrix of size 5 as the kernel 
kernel_to_dilate = np.ones((6,2), np.uint8) 
kernel_to_erode = np.ones((5,2), np.uint8)
# The first parameter is the original image, 
# kernel is the matrix with which image is  
# convolved and third parameter is the number  
# of iterations, which will determine how much  
# you want to erode/dilate a given image.  
img_dilation = cv2.dilate(img, kernel_to_dilate, iterations=1) 
img_erosion = cv2.erode(img_dilation, kernel_to_erode, iterations=1) 
  
plt.imshow(img, cmap='gray')
plt.show()
plt.imshow(img_dilation,cmap='gray')
plt.show()
plt.imshow(img_erosion,cmap='gray')
plt.show()

# cv2.imwrite('maskedcroppeddilated.png', img_dilation)

# cv2.imshow('Erosion', img_erosion) 
# cv2.imshow('Dilation', img_dilation) 
  
# cv2.waitKey(0)

# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt  
# Reading the input image 
img = cv2.imread('maskingcropped.png', 0) 
# Taking a matrix of size 5 as the kernel 
kernel_to_dilate = np.ones((6,2), np.uint8) 
kernel_to_erode = np.ones((6,2), np.uint8)
# The first parameter is the original image, 
# kernel is the matrix with which image is  
# convolved and third parameter is the number  
# of iterations, which will determine how much  
# you want to erode/dilate a given image.  
img_dilation = cv2.dilate(img, kernel_to_dilate, iterations=1) 
# img_erosion = cv2.erode(img_dilation, kernel_to_erode, iterations=1) 
  
plt.imshow(img, cmap='gray')
plt.show()
plt.imshow(img_dilation,cmap='gray')
plt.show()
# plt.imshow(img_erosion,cmap='gray')
# plt.show()

cv2.imwrite('maskedcroppeddilated.png', img_dilation)

# cv2.imshow('Erosion', img_erosion) 
# cv2.imshow('Dilation', img_dilation) 
  
# cv2.waitKey(0)
# Out:
# (169, 541)
# True

# %%
img = cv2.imread('maskedcroppeddilated.png', 0) 
size = np.size(img)
skel = np.zeros(img.shape,np.uint8)
plt.rcParams["figure.figsize"] = (25,15)
# ret,img = cv2.threshold(img,127,255,0)
element = cv2.getStructuringElement(cv2.MORPH_CROSS,(1,1))
done = False
 
while (not done):
    eroded = cv2.erode(img,element)
    temp = cv2.dilate(eroded,element)
    temp = cv2.subtract(img,temp)
    skel = cv2.bitwise_or(skel,temp)
    img = eroded.copy()
 
    zeros = size - cv2.countNonZero(img)
    if zeros==size:
        done = True
 
plt.imshow(skel,cmap='gray')
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt  
# Reading the input image 
img = cv2.imread('masking.png', 0) 
  
# Taking a matrix of size 5 as the kernel

kernel_to_dilate = np.ones((5,3), np.uint8) 
kernel_to_erode = np.ones((4,3), np.uint8)

# The first parameter is the original image, 
# kernel is the matrix with which image is  
# convolved and third parameter is the number  
# of iterations, which will determine how much  
# you want to erode/dilate a given image.  
img_dilation = cv2.dilate(img, kernel_to_dilate, iterations=1) 
img_erosion = cv2.erode(img_dilation, kernel_to_erode, iterations=1) 
  
plt.imshow(img, cmap='gray')
plt.show()
plt.imshow(img_dilation,cmap='gray')
plt.show()
plt.imshow(img_erosion,cmap='gray')
plt.show()

# cv2.imwrite('maskedcroppeddilated.png', img_dilation)

# cv2.imshow('Erosion', img_erosion) 
# cv2.imshow('Dilation', img_dilation) 
  
# cv2.waitKey(0)

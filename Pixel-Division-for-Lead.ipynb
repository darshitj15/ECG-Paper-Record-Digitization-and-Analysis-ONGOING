# %%
from PIL import Image 
import matplotlib.pyplot as plt 
import os
import glob

# %%
os.chdir('..')

# %%
entries = glob.glob('*.png')
entries

# %%
os.chdir(r"..")
os.getcwd()
# Out:
# 'D:\\ECG Project\\sports\\1'

# %%
os.chdir('D:\\ECG Project\\sports\\1')
entries = glob.glob('*.png')

# %%
entries = glob.glob('*.png')
for i in entries:
    im = Image.open(i)
    width, height = im.size 
    left = width/13.49           #163
    top = height/3.4               #2200,1700
    right = width/4.19
    bottom = height/2.65625
    im1 = im.crop((left, top, right, bottom)) 
    im1.save(r'lead1\1-'+i)  
entries = glob.glob('*.png')
for i in entries:
    im = Image.open(i)
    width, height = im.size 
    left2 = width/2.99
    top2 = height/3.4
    right2 = width/1.9469
    bottom2 = height/2.5373
    im2 = im.crop((left2, top2, right2, bottom2)) 
    im2.save(r'lead2\1-'+i)

for i in entries:
    im = Image.open(i)
    width, height = im.size 

    left3 = width/1.8640
    top3 = height/3.4
    right3 = width/1.4473
    bottom3 = height/2.5373
    im3 = im.crop((left3, top3, right3, bottom3)) 
    im3.save(r'lead3\1-'+i)

for i in entries:
    im = Image.open(i)
    left4 = width/1.2941
    top4 = height/3.4
    right4 = width/1.0377
    bottom4 = height/2.5373
    #  
    # Cropped image of above dimension 
    # (It will not change orginal image) 
    im4 = im.crop((left4, top4, right4, bottom4)) 
    im4.save(r'lead4\1-'+i)

    
for i in entries:
    im = Image.open(i)
    left5 = width/12.7167
    top5 = height/2.65625
    right5 = width/3.9639
    bottom5 = height/2
    #  
    # Cropped image of above dimension 
    # (It will not change orginal image) 
    im5 = im.crop((left5, top5, right5, bottom5)) 
    im5.save(r'lead5\1-'+i)

for i in entries:
    im = Image.open(i)
    left6 = width/2.9931
    top6 = height/2.5373
    right6 = width/1.9469
    bottom6 = height/2
    im6 = im.crop((left6, top6, right6, bottom6)) 
    im6.save(r'lead6\1-'+i)

# %%
os.chdir('D:\\ECG Project\\sports\\F-1')
entries = glob.glob('*.png')

# %%
#2

entries = glob.glob('*.png')
for i in entries:
    im = Image.open(i)
    width, height = im.size 
    left2 = width/2.99
    top2 = height/3.4
    right2 = width/1.9469
    bottom2 = height/2.5373
    im2 = im.crop((left2, top2, right2, bottom2)) 
    im2.save(r'lead2\1-'+i)

# %%
im = Image.open(r"2/2-1.png") 
width, height = im.size
left1 = width/13.49           #163
top1 = height/3.4               #2200,1700
right1 = width/4.19
bottom1 = height/2.65625
#  
# Cropped image of above dimension 
# (It will not change orginal image) 
im1 = im.crop((left1, top1, right1, bottom1)) 
  
# Shows the image in image viewer 
plt.imshow(im1)

# %%
im = Image.open(r"2/2-1.png") 

left2 = width/2.99
top2 = height/3.4
right2 = width/1.9469
bottom2 = height/2.5373#  
# Cropped image of above dimension 
# (It will not change orginal image) 
im2 = im.crop((left2, top2, right2, bottom2)) 
  
# Shows the image in image viewer 
plt.imshow(im2)

# %%
im = Image.open(r"2/2-1.png") 

left3 = width/1.8640
top3 = height/3.4
right3 = width/1.4473
bottom3 = height/2.5373
#  
# Cropped image of above dimension 
# (It will not change orginal image) 
im3 = im.crop((left3, top3, right3, bottom3)) 
  
# Shows the image in image viewer 
plt.imshow(im3)

# %%
im = Image.open(r"2/2-1.png") 

left4 = width/1.2941
top4 = height/3.4
right4 = width/1.0377
bottom4 = height/2.5373
#  
# Cropped image of above dimension 
# (It will not change orginal image) 
im4 = im.crop((left4, top4, right4, bottom4)) 
  
# Shows the image in image viewer 
plt.imshow(im4)

# %%
im = Image.open(r"2/2-1.png") 

left5 = width/12.7167
top5 = height/2.65625
right5 = width/3.9639
bottom5 = height/2
#  
# Cropped image of above dimension 
# (It will not change orginal image) 
im5 = im.crop((left5, top5, right5, bottom5)) 
  
# Shows the image in image viewer 
plt.imshow(im5)

# %%
im = Image.open(r"2/2-1.png") 

left6 = width/2.9931
top6 = height/2.5373
right6 = width/1.9469
bottom6 = height/2
#  
# Cropped image of above dimension 
# (It will not change orginal image) 
im6 = im.crop((left6, top6, right6, bottom6)) 
  
# Shows the image in image viewer 
plt.imshow(im6)

# %%
im = Image.open(r"/Users/varunvala/Downloads/trial.ppm") 

left7 = 1180
top7 = 670
right7 = 1520
bottom7 = 850
#  
# Cropped image of above dimension 
# (It will not change orginal image) 
im7 = im.crop((left7, top7, right7, bottom7)) 
  
# Shows the image in image viewer 
plt.imshow(im7)

# %%
im = Image.open(r"/Users/varunvala/Downloads/trial.ppm") 

left8 = 1700
top8 = 670
right8 = 2105
bottom8 = 850
#  
# Cropped image of above dimension 
# (It will not change orginal image) 
im8 = im.crop((left8, top8, right8, bottom8)) 
  
# Shows the image in image viewer 
plt.imshow(im8)

# %%
im = Image.open(r"/Users/varunvala/Downloads/trial.ppm") 

left9 = 183
top9 = 850
right9 = 550
bottom9 = 1000
#  
# Cropped image of above dimension 
# (It will not change orginal image) 
im9 = im.crop((left9, top9, right9, bottom9)) 
  
# Shows the image in image viewer 
plt.imshow(im9)

# %%
im = Image.open(r"/Users/varunvala/Downloads/trial.ppm") 

left10 = 730
top10 = 850
right10 = 1130
bottom10 = 1000
#  
# Cropped image of above dimension 
# (It will not change orginal image) 
im10 = im.crop((left10, top10, right10, bottom10)) 
  
# Shows the image in image viewer 
plt.imshow(im10)

# %%
im = Image.open(r"/Users/varunvala/Downloads/trial.ppm") 

left11 = 1180
top11 = 850
right11 = 1520
bottom11 = 1000
#  
# Cropped image of above dimension 
# (It will not change orginal image) 
im11 = im.crop((left11, top11, right11, bottom11)) 
  
# Shows the image in image viewer 
plt.imshow(im11)

# %%
im = Image.open(r"/Users/varunvala/Downloads/trial.ppm") 

left12 = 1730
top12 = 850
right12 = 2105
bottom12 = 1000
#  
# Cropped image of above dimension 
# (It will not change orginal image) 
im12 = im.crop((left12, top12, right12, bottom12)) 
  
# Shows the image in image viewer 
plt.imshow(im12)
